# %% [markdown]
# <a href="https://colab.research.google.com/github/F-Emm/hamoye-/blob/boss/Hamoye_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

print(pd.__version__)
# Out:
# 1.1.5

# %% [markdown]
# # Data Table Display
#
# Colab includes an extension that renders pandas dataframes into interactive displays that can be filtered, sorted, and explored dynamically.
#
# Data table display for Pandas dataframes can be enabled by running:
# ```python
# from google.colab import data_table
# data_table.enable_dataframe_formatter()
# ```
# and disabled by running
# ```python
# from google.colab import data_table
# data_table.disable_dataframe_formatter()
# ```

# %%
url = 'https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'
df = pd.read_csv(url, error_bad_lines = False, encoding = 'latin-1')

print(df.head(5))
# Out:
#    Area Code     Area  Item Code  ...     Y2016     Y2017     Y2018
# 0          4  Algeria       2501  ...  40551.00  41389.00  42228.00
# 1          4  Algeria       2501  ...      0.00      0.00      0.00
# 2          4  Algeria       2901  ...   3372.00   3341.00   3322.00
# 3          4  Algeria       2901  ...     94.72     92.82     91.83
# 4          4  Algeria       2901  ...     77.40     80.19     77.28
#
# [5 rows x 12 columns]

# %%
#enabling tables

from google.colab import data_table
from vega_datasets import data

data_table.disable_dataframe_formatter()
df.head(5)
# Out:
#    Area Code     Area  Item Code  ...     Y2016     Y2017     Y2018
# 0          4  Algeria       2501  ...  40551.00  41389.00  42228.00
# 1          4  Algeria       2501  ...      0.00      0.00      0.00
# 2          4  Algeria       2901  ...   3372.00   3341.00   3322.00
# 3          4  Algeria       2901  ...     94.72     92.82     91.83
# 4          4  Algeria       2901  ...     77.40     80.19     77.28
#
# [5 rows x 12 columns]

# %%
#disabling tables

#from google.colab import data_table
#data_table.disable_dataframe_formatter()

#data.airports()

# %%
#from google.colab import data_table
#from vega_datasets import data

#data_table.disable_dataframe_formatter() 
#df.loc[(df['Item'] == 'Animal Products') & (df['Element'] == 'Fat supply quantity (g/capita/day)')] = pd.Series(df['Y2014'].sum(), index = ['Y2014'])
fat = df.loc[(df['Item'] == 'Animal Products') & (df['Element'] == 'Fat supply quantity (g/capita/day)')]
#fat2014 = df.loc[('Y2014') == 'Y2014']
#df['Y2014'] =
#print(fat)
#new_df = fat
fat.to_csv('fat_filtered.csv', index = False)
#print(fat)
fat = pd.read_csv('fat_filtered.csv', error_bad_lines = False)
#fat.head(5)
#fat.head(-1)
fat['Y2014'].sum()
#fat.groupby(['Y2014']).sum()
# finding sum over index axis
# By default the axis is set to 0
#fat.sum(axis = 0, skipna = True)

#df.groupby((df['Y2014']) & (['fat'])).sum()
#df.describe()
#names_in_both = list(set(Y2017).intersection(fat))
# Out:
# 661.4199999999998

# %% [markdown]
# # ***Question 11 Answer below, after trying to do it with above.***

# %%
df.groupby(["Item"])["Y2014", "Y2017"].sum()
#df.groupby("Item")["Item"].count().to_frame()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %% [markdown]
# # ***Question 12 & 13 answers gotten below***

# %%
#df.at['Fat supply', 'Item']
#df.mean()
#df.std()
#df.describe()
#df.sum()
#df.isnull().sum()
#df.isin(df).sum()
#print(1535/59408)
# Out:
# 0.02583827093994075

# %% [markdown]
# # ***Question 14 answer***

# %%
#df.describe()

# To find the correlation among
# the columns using pearson method
df.corr(method ='pearson')
# Out:
#               Area Code  Item Code  Element Code  ...     Y2016     Y2017     Y2018
# Area Code      1.000000  -0.005159     -0.000209  ...  0.005247  0.005006  0.005665
# Item Code     -0.005159   1.000000     -0.024683  ...  0.020109  0.021494  0.021314
# Element Code  -0.000209  -0.024683      1.000000  ...  0.023444  0.024254  0.024279
# Y2014          0.006164   0.021722      0.024457  ...  0.996081  0.995230  0.994872
# Y2015          0.005472   0.020857      0.023889  ...  0.995739  0.988048  0.988208
# Y2016          0.005247   0.020109      0.023444  ...  1.000000  0.992785  0.992757
# Y2017          0.005006   0.021494      0.024254  ...  0.992785  1.000000  0.998103
# Y2018          0.005665   0.021314      0.024279  ...  0.992757  0.998103  1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# # ***Question 15 Answer below***

# %%
#df.groupby
subset_df = df[df["Element"] == 'Import Quantity']
column_sum = subset_df.sum()
column_sum.to_frame()
# Out:
#                                                               0
# Area Code                                                688174
# Area          AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                              13795966
# Item          Cereals - Excluding BeerWheat and productsRice...
# Element Code                                           28834929
# Element       Import QuantityImport QuantityImport QuantityI...
# Unit          1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                    274144
# Y2015                                                    267018
# Y2016                                                    286583
# Y2017                                                    294559
# Y2018                                                    287997

# %% [markdown]
# # ***Question 16 Answer***

# %%
#df.groupby(["Element" == 'Production']).describe()
df.groupby(["Element"])["Y2014", "Y2017"].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                              Y2014       Y2017
# Element
# Domestic supply quantity                1996716.35  2088198.10
# Export Quantity                          150020.64   182338.80
# Fat supply quantity (g/capita/day)        10225.56    10253.84
# Feed                                     216927.89   223705.68
# Food                                    1212332.49  1258888.28
# Food supply (kcal/capita/day)            454257.00   454681.00
# Food supply quantity (kg/capita/yr)       49650.63    48690.04
# Import Quantity                          274144.48   294559.09
# Losses                                   153223.00   160614.00
# Other uses (non-food)                     78718.13    91645.97
# Processing                               282923.00   292836.00
# ...

# %% [markdown]
# # ***Question 17 Answer below***

# %%
df.groupby(["Element"])["Y2018"].sum().to_frame()
# shows the answers is domestic supply quantity as the highest in Y2018
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %% [markdown]
# # ***Question 18 Answer below***

# %%
df.groupby(["Element"])["Y2018"].sum().to_frame().sort_values(by = "Y2018", ascending = True)
#Protein supply Quantity is the 3rd lowest in Y2018
# Out:
#                                              Y2018
# Element
# Tourist consumption                          90.00
# Fat supply quantity (g/capita/day)        10258.69
# Protein supply quantity (g/capita/day)    11833.56
# Stock Variation                           20577.91
# Seed                                      25263.14
# Residuals                                 34864.00
# Food supply quantity (kg/capita/yr)       49056.85
# Other uses (non-food)                     91300.97
# Losses                                   163902.00
# Export Quantity                          181594.80
# Feed                                     233489.68
# Import Quantity                          287997.09
# Processing                               308429.00
# Food supply (kcal/capita/day)            455261.00
# Total Population - Both sexes           1140605.00
# Food                                    1303841.28
# Production                              2075072.89
# ...

# %% [markdown]
# # ***Question 19 Answer below***

# %%
df_alg = df.groupby(["Element", "Area"])["Y2014", "Y2015", "Y2016", "Y2017", "Y2018"].sum()
df_alg['Total'] = df_alg.sum(axis =1)
df_alg.to_dict() #this works but not optimal
#df_alg.to_excel(csv)

#subset_df = df[df["Element"] == 'Import Quantity']
#column_sum = subset_df.sum()
#column_sum.to_frame()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# {'Total': {('Domestic supply quantity', 'Algeria'): 433720.25,
#   ('Domestic supply quantity', 'Angola'): 281644.94,
#   ('Domestic supply quantity', 'Benin'): 151756.56,
#   ('Domestic supply quantity', 'Botswana'): 14134.510000000006,
#   ('Domestic supply quantity', 'Burkina Faso'): 121775.5,
#   ('Domestic supply quantity', 'Cabo Verde'): 3725.4700000000003,
#   ('Domestic supply quantity', 'Cameroon'): 311680.33999999997,
#   ('Domestic supply quantity', 'Central African Republic'): 27048.299999999996,
#   ('Domestic supply quantity', 'Chad'): 74931.44,
#   ('Domestic supply quantity', 'Comoros'): 82.66,
#   ('Domestic supply quantity', 'Congo'): 40087.75,
#   ('Domestic supply quantity', "Côte d'Ivoire"): 262302.44,
# ...

# %% [markdown]
# # ***Question 20 Answer below***

# %%
df.Area.nunique()

#or

#df[['Area']].agg(['count', 'size', 'nunique'])

#testing values below can work on other vales
#df.Area.value_counts().Area
#df.apply(pd.value_counts)
#df['Area'].value_counts().ColValue
#df['Area'].value_counts(ascending = True)
#df['Area'].value_counts(normalize=True) # => gives %age values of the counted list
# Out:
# 49

# %%
#df['Y2014', 'products'].sum()

# %%
#df.loc[(df['Item'] == 'Animal Products') & (df['Element'] == 'Fat supply quantity (g/capita/day)')] = pd.Series(df['Y2014'].sum(), index = ['Y2014'])#

# %%
#df.groupby(['Y2017']).sum()

# %% [markdown]
# https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv

# %% [markdown]
# The dataset is provided by the Food and Agriculture Organization of the United Nations and is made available in .csv format on the github link below-
#
# https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning
#
# Features
#
# Area Code',
#
# 'Area',
#
# 'Item Code',
#
# 'Item',
#
# 'Element Code',
#
# 'Element',
#
# 'Unit',
#
# 'Y2014',
#
# 'Y2015',
#
# 'Y2016',
#
# 'Y2017',
#
# 'Y2018'
#
# Answer questions 11- 20 based on the data.
#
# After completion of the assessment, you are required to submit the link to your code using this Google Form.
#
# Please note that plagiarism is highly prohibited and you will be disqualified if found guilty of it.
